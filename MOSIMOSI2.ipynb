# %%
# %matplotlib notebook

import math
import numpy as np
import matplotlib.pyplot as plt
from matplotlib.animation import FuncAnimation



fig, ax = plt.subplots()
ax.set_xlim(0, 50)
ax.set_ylim(0, 20)
line, = ax.plot([], [])



#mempertimbangkan massa benda
x = 0
y = 0
g = 9.806
m = 0.15
D = 0.0013

theta = math.radians(35)
sinTheta = math.sin(theta)
cosTheta = math.cos(theta)

Vo = 50
Vx = Vo * cosTheta
Vy = Vo * sinTheta
V = math.sqrt((Vy * Vy) + (Vx * Vx))

ax = -(D/m) * V * Vx
ay = -g-(D/m) * V * Vy

t = 0
deltaT = 0.01

storeX = []
storeY = []


print('============ NUMERIK ============')
while True:
    Vx = Vx + (ax * deltaT)
    Vy = Vy + (ay * deltaT)
    x = x + (Vx * deltaT)
    y = y + (Vy * deltaT)
    t = t + deltaT
    print('Posisi di sumbu Y = ',round(y,5))
    print('Posisi di sumbu X = ',round(x,5))
    print('Waktu = ',round(t,2),' s')
    print()
    storeX.append(x)
    storeY.append(y)
    if(y <= 0):
        break


dataX = []
dataY = []
  
def animation_frame(i):
	dataX.append(storeX[i])
	dataY.append(storeY[i])

	line.set_data(dataX, dataY)
	return line, 
plt.title('Grafik Gerak Peluru Mempertimbangkan Hambatan')

animation = FuncAnimation(fig, func=animation_frame, frames=1000, interval=40)
plt.show()


print('============ ANALITIK ============')
x = 0
y = 0

Vx = Vo * cosTheta
Vy = Vo * sinTheta

x = x + (Vx * t) + (0.5 * ax * t * t)
y = y + (Vy * t) + (0.5 * ay * t * t)

print('Posisi di sumbu Y = ',round(y,5))
print('Posisi di sumbu X = ',round(x,5))
print('Waktu = ',round(t,2),' s')
# Out:
# <img src="data:image/png;base64,..." width="640">
# ============ NUMERIK ============
# Posisi di sumbu Y =  0.28456
# Posisi di sumbu X =  0.4078
# Waktu =  0.01  s
#
# Posisi di sumbu Y =  0.56691
# Posisi di sumbu X =  0.81383
# Waktu =  0.02  s
#
# Posisi di sumbu Y =  0.84702
# Posisi di sumbu X =  1.21808
# Waktu =  0.03  s
#
# Posisi di sumbu Y =  1.12492
# Posisi di sumbu X =  1.62056
# Waktu =  0.04  s
#
# Posisi di sumbu Y =  1.40059
# Posisi di sumbu X =  2.02126
# Waktu =  0.05  s
#
# Posisi di sumbu Y =  1.67404
# Posisi di sumbu X =  2.42018
# Waktu =  0.06  s
#
# Posisi di sumbu Y =  1.94526
# Posisi di sumbu X =  2.81734
# Waktu =  0.07  s
#
# Posisi di sumbu Y =  2.21427
# Posisi di sumbu X =  3.21271
# Waktu =  0.08  s
#
# Posisi di sumbu Y =  2.48104
# Posisi di sumbu X =  3.60632
# Waktu =  0.09  s
#
# Posisi di sumbu Y =  2.7456
# Posisi di sumbu X =  3.99814
# Waktu =  0.1  s
#
# Posisi di sumbu Y =  3.00793
# Posisi di sumbu X =  4.3882
# Waktu =  0.11  s
#
# Posisi di sumbu Y =  3.26804
# Posisi di sumbu X =  4.77648
# Waktu =  0.12  s
#
# Posisi di sumbu Y =  3.52592
# Posisi di sumbu X =  5.16298
# Waktu =  0.13  s
#
# Posisi di sumbu Y =  3.78158
# Posisi di sumbu X =  5.54771
# Waktu =  0.14  s
#
# Posisi di sumbu Y =  4.03502
# Posisi di sumbu X =  5.93066
# Waktu =  0.15  s
#
# Posisi di sumbu Y =  4.28624
# Posisi di sumbu X =  6.31184
# Waktu =  0.16  s
#
# Posisi di sumbu Y =  4.53523
# Posisi di sumbu X =  6.69124
# Waktu =  0.17  s
#
# Posisi di sumbu Y =  4.782
# Posisi di sumbu X =  7.06887
# Waktu =  0.18  s
#
# Posisi di sumbu Y =  5.02654
# Posisi di sumbu X =  7.44473
# Waktu =  0.19  s
#
# Posisi di sumbu Y =  5.26886
# Posisi di sumbu X =  7.81881
# Waktu =  0.2  s
#
# Posisi di sumbu Y =  5.50896
# Posisi di sumbu X =  8.19111
# Waktu =  0.21  s
#
# Posisi di sumbu Y =  5.74683
# Posisi di sumbu X =  8.56164
# Waktu =  0.22  s
#
# Posisi di sumbu Y =  5.98248
# Posisi di sumbu X =  8.9304
# Waktu =  0.23  s
#
# Posisi di sumbu Y =  6.21591
# Posisi di sumbu X =  9.29738
# Waktu =  0.24  s
#
# Posisi di sumbu Y =  6.44712
# Posisi di sumbu X =  9.66258
# Waktu =  0.25  s
#
# Posisi di sumbu Y =  6.6761
# Posisi di sumbu X =  10.02601
# Waktu =  0.26  s
#
# Posisi di sumbu Y =  6.90286
# Posisi di sumbu X =  10.38767
# Waktu =  0.27  s
#
# Posisi di sumbu Y =  7.12739
# Posisi di sumbu X =  10.74755
# Waktu =  0.28  s
#
# Posisi di sumbu Y =  7.3497
# Posisi di sumbu X =  11.10565
# Waktu =  0.29  s
#
# Posisi di sumbu Y =  7.56979
# Posisi di sumbu X =  11.46198
# Waktu =  0.3  s
#
# Posisi di sumbu Y =  7.78765
# Posisi di sumbu X =  11.81654
# Waktu =  0.31  s
#
# Posisi di sumbu Y =  8.00329
# Posisi di sumbu X =  12.16932
# Waktu =  0.32  s
#
# Posisi di sumbu Y =  8.21671
# Posisi di sumbu X =  12.52033
# Waktu =  0.33  s
#
# Posisi di sumbu Y =  8.42791
# Posisi di sumbu X =  12.86956
# Waktu =  0.34  s
#
# Posisi di sumbu Y =  8.63688
# Posisi di sumbu X =  13.21702
# Waktu =  0.35  s
#
# Posisi di sumbu Y =  8.84363
# Posisi di sumbu X =  13.5627
# Waktu =  0.36  s
#
# Posisi di sumbu Y =  9.04815
# Posisi di sumbu X =  13.90661
# Waktu =  0.37  s
#
# Posisi di sumbu Y =  9.25045
# Posisi di sumbu X =  14.24874
# Waktu =  0.38  s
#
# Posisi di sumbu Y =  9.45053
# Posisi di sumbu X =  14.5891
# Waktu =  0.39  s
#
# Posisi di sumbu Y =  9.64838
# Posisi di sumbu X =  14.92768
# Waktu =  0.4  s
#
# Posisi di sumbu Y =  9.84401
# Posisi di sumbu X =  15.26449
# Waktu =  0.41  s
#
# Posisi di sumbu Y =  10.03742
# Posisi di sumbu X =  15.59952
# Waktu =  0.42  s
#
# Posisi di sumbu Y =  10.22861
# Posisi di sumbu X =  15.93278
# Waktu =  0.43  s
#
# Posisi di sumbu Y =  10.41757
# Posisi di sumbu X =  16.26426
# Waktu =  0.44  s
#
# Posisi di sumbu Y =  10.6043
# Posisi di sumbu X =  16.59397
# Waktu =  0.45  s
#
# Posisi di sumbu Y =  10.78882
# Posisi di sumbu X =  16.92191
# Waktu =  0.46  s
#
# Posisi di sumbu Y =  10.97111
# Posisi di sumbu X =  17.24807
# Waktu =  0.47  s
#
# Posisi di sumbu Y =  11.15118
# Posisi di sumbu X =  17.57245
# Waktu =  0.48  s
#
# Posisi di sumbu Y =  11.32902
# Posisi di sumbu X =  17.89506
# Waktu =  0.49  s
#
# Posisi di sumbu Y =  11.50464
# Posisi di sumbu X =  18.21589
# Waktu =  0.5  s
#
# Posisi di sumbu Y =  11.67804
# Posisi di sumbu X =  18.53495
# Waktu =  0.51  s
#
# Posisi di sumbu Y =  11.84921
# Posisi di sumbu X =  18.85224
# Waktu =  0.52  s
#
# Posisi di sumbu Y =  12.01816
# Posisi di sumbu X =  19.16775
# Waktu =  0.53  s
#
# Posisi di sumbu Y =  12.18489
# Posisi di sumbu X =  19.48148
# Waktu =  0.54  s
#
# Posisi di sumbu Y =  12.34939
# Posisi di sumbu X =  19.79344
# Waktu =  0.55  s
#
# Posisi di sumbu Y =  12.51168
# Posisi di sumbu X =  20.10363
# Waktu =  0.56  s
#
# Posisi di sumbu Y =  12.67173
# Posisi di sumbu X =  20.41204
# Waktu =  0.57  s
#
# Posisi di sumbu Y =  12.82957
# Posisi di sumbu X =  20.71868
# Waktu =  0.58  s
#
# Posisi di sumbu Y =  12.98518
# Posisi di sumbu X =  21.02354
# Waktu =  0.59  s
#
# Posisi di sumbu Y =  13.13856
# Posisi di sumbu X =  21.32662
# Waktu =  0.6  s
#
# Posisi di sumbu Y =  13.28973
# Posisi di sumbu X =  21.62793
# Waktu =  0.61  s
#
# Posisi di sumbu Y =  13.43867
# Posisi di sumbu X =  21.92747
# Waktu =  0.62  s
#
# Posisi di sumbu Y =  13.58539
# Posisi di sumbu X =  22.22523
# Waktu =  0.63  s
#
# Posisi di sumbu Y =  13.72988
# Posisi di sumbu X =  22.52122
# Waktu =  0.64  s
#
# Posisi di sumbu Y =  13.87215
# Posisi di sumbu X =  22.81543
# Waktu =  0.65  s
#
# Posisi di sumbu Y =  14.0122
# Posisi di sumbu X =  23.10787
# Waktu =  0.66  s
#
# Posisi di sumbu Y =  14.15002
# Posisi di sumbu X =  23.39853
# Waktu =  0.67  s
#
# Posisi di sumbu Y =  14.28562
# Posisi di sumbu X =  23.68742
# Waktu =  0.68  s
#
# Posisi di sumbu Y =  14.419
# Posisi di sumbu X =  23.97453
# Waktu =  0.69  s
#
# Posisi di sumbu Y =  14.55015
# Posisi di sumbu X =  24.25987
# Waktu =  0.7  s
#
# Posisi di sumbu Y =  14.67908
# Posisi di sumbu X =  24.54343
# Waktu =  0.71  s
#
# Posisi di sumbu Y =  14.80579
# Posisi di sumbu X =  24.82522
# Waktu =  0.72  s
#
# Posisi di sumbu Y =  14.93027
# Posisi di sumbu X =  25.10524
# Waktu =  0.73  s
#
# Posisi di sumbu Y =  15.05253
# Posisi di sumbu X =  25.38347
# Waktu =  0.74  s
#
# Posisi di sumbu Y =  15.17257
# Posisi di sumbu X =  25.65994
# Waktu =  0.75  s
#
# Posisi di sumbu Y =  15.29039
# Posisi di sumbu X =  25.93463
# Waktu =  0.76  s
#
# Posisi di sumbu Y =  15.40598
# Posisi di sumbu X =  26.20754
# Waktu =  0.77  s
#
# Posisi di sumbu Y =  15.51934
# Posisi di sumbu X =  26.47868
# Waktu =  0.78  s
#
# Posisi di sumbu Y =  15.63049
# Posisi di sumbu X =  26.74804
# Waktu =  0.79  s
#
# Posisi di sumbu Y =  15.73941
# Posisi di sumbu X =  27.01563
# Waktu =  0.8  s
#
# Posisi di sumbu Y =  15.8461
# Posisi di sumbu X =  27.28145
# Waktu =  0.81  s
#
# Posisi di sumbu Y =  15.95058
# Posisi di sumbu X =  27.54549
# Waktu =  0.82  s
#
# Posisi di sumbu Y =  16.05283
# Posisi di sumbu X =  27.80775
# Waktu =  0.83  s
#
# Posisi di sumbu Y =  16.15285
# Posisi di sumbu X =  28.06824
# Waktu =  0.84  s
#
# Posisi di sumbu Y =  16.25066
# Posisi di sumbu X =  28.32696
# Waktu =  0.85  s
#
# Posisi di sumbu Y =  16.34624
# Posisi di sumbu X =  28.5839
# Waktu =  0.86  s
#
# Posisi di sumbu Y =  16.4396
# Posisi di sumbu X =  28.83907
# Waktu =  0.87  s
#
# Posisi di sumbu Y =  16.53073
# Posisi di sumbu X =  29.09246
# Waktu =  0.88  s
#
# Posisi di sumbu Y =  16.61964
# Posisi di sumbu X =  29.34407
# Waktu =  0.89  s
#
# Posisi di sumbu Y =  16.70633
# Posisi di sumbu X =  29.59392
# Waktu =  0.9  s
#
# Posisi di sumbu Y =  16.79079
# Posisi di sumbu X =  29.84198
# Waktu =  0.91  s
#
# Posisi di sumbu Y =  16.87303
# Posisi di sumbu X =  30.08827
# Waktu =  0.92  s
#
# Posisi di sumbu Y =  16.95305
# Posisi di sumbu X =  30.33279
# Waktu =  0.93  s
#
# Posisi di sumbu Y =  17.03084
# Posisi di sumbu X =  30.57553
# Waktu =  0.94  s
#
# Posisi di sumbu Y =  17.10641
# Posisi di sumbu X =  30.8165
# Waktu =  0.95  s
#
# Posisi di sumbu Y =  17.17976
# Posisi di sumbu X =  31.05569
# Waktu =  0.96  s
#
# Posisi di sumbu Y =  17.25088
# Posisi di sumbu X =  31.29311
# Waktu =  0.97  s
#
# Posisi di sumbu Y =  17.31978
# Posisi di sumbu X =  31.52875
# Waktu =  0.98  s
#
# Posisi di sumbu Y =  17.38646
# Posisi di sumbu X =  31.76262
# Waktu =  0.99  s
#
# Posisi di sumbu Y =  17.45091
# Posisi di sumbu X =  31.99471
# Waktu =  1.0  s
#
# Posisi di sumbu Y =  17.51314
# Posisi di sumbu X =  32.22503
# Waktu =  1.01  s
#
# Posisi di sumbu Y =  17.57315
# Posisi di sumbu X =  32.45358
# Waktu =  1.02  s
#
# Posisi di sumbu Y =  17.63093
# Posisi di sumbu X =  32.68034
# Waktu =  1.03  s
#
# Posisi di sumbu Y =  17.68649
# Posisi di sumbu X =  32.90534
# Waktu =  1.04  s
#
# Posisi di sumbu Y =  17.73983
# Posisi di sumbu X =  33.12856
# Waktu =  1.05  s
#
# Posisi di sumbu Y =  17.79094
# Posisi di sumbu X =  33.35
# Waktu =  1.06  s
#
# Posisi di sumbu Y =  17.83983
# Posisi di sumbu X =  33.56967
# Waktu =  1.07  s
#
# Posisi di sumbu Y =  17.8865
# Posisi di sumbu X =  33.78756
# Waktu =  1.08  s
#
# Posisi di sumbu Y =  17.93094
# Posisi di sumbu X =  34.00368
# Waktu =  1.09  s
#
# Posisi di sumbu Y =  17.97316
# Posisi di sumbu X =  34.21803
# Waktu =  1.1  s
#
# Posisi di sumbu Y =  18.01316
# Posisi di sumbu X =  34.4306
# Waktu =  1.11  s
#
# Posisi di sumbu Y =  18.05093
# Posisi di sumbu X =  34.64139
# Waktu =  1.12  s
#
# Posisi di sumbu Y =  18.08648
# Posisi di sumbu X =  34.85041
# Waktu =  1.13  s
#
# Posisi di sumbu Y =  18.1198
# Posisi di sumbu X =  35.05766
# Waktu =  1.14  s
#
# Posisi di sumbu Y =  18.15091
# Posisi di sumbu X =  35.26313
# Waktu =  1.15  s
#
# Posisi di sumbu Y =  18.17979
# Posisi di sumbu X =  35.46683
# Waktu =  1.16  s
#
# Posisi di sumbu Y =  18.20644
# Posisi di sumbu X =  35.66875
# Waktu =  1.17  s
#
# Posisi di sumbu Y =  18.23088
# Posisi di sumbu X =  35.86889
# Waktu =  1.18  s
#
# Posisi di sumbu Y =  18.25309
# Posisi di sumbu X =  36.06726
# Waktu =  1.19  s
#
# Posisi di sumbu Y =  18.27307
# Posisi di sumbu X =  36.26386
# Waktu =  1.2  s
#
# Posisi di sumbu Y =  18.29084
# Posisi di sumbu X =  36.45868
# Waktu =  1.21  s
#
# Posisi di sumbu Y =  18.30638
# Posisi di sumbu X =  36.65173
# Waktu =  1.22  s
#
# Posisi di sumbu Y =  18.31969
# Posisi di sumbu X =  36.843
# Waktu =  1.23  s
#
# Posisi di sumbu Y =  18.33078
# Posisi di sumbu X =  37.0325
# Waktu =  1.24  s
#
# Posisi di sumbu Y =  18.33965
# Posisi di sumbu X =  37.22022
# Waktu =  1.25  s
#
# Posisi di sumbu Y =  18.3463
# Posisi di sumbu X =  37.40617
# Waktu =  1.26  s
#
# Posisi di sumbu Y =  18.35072
# Posisi di sumbu X =  37.59034
# Waktu =  1.27  s
#
# Posisi di sumbu Y =  18.35292
# Posisi di sumbu X =  37.77274
# Waktu =  1.28  s
#
# Posisi di sumbu Y =  18.3529
# Posisi di sumbu X =  37.95336
# Waktu =  1.29  s
#
# Posisi di sumbu Y =  18.35065
# Posisi di sumbu X =  38.13221
# Waktu =  1.3  s
#
# Posisi di sumbu Y =  18.34618
# Posisi di sumbu X =  38.30928
# Waktu =  1.31  s
#
# Posisi di sumbu Y =  18.33949
# Posisi di sumbu X =  38.48458
# Waktu =  1.32  s
#
# Posisi di sumbu Y =  18.33057
# Posisi di sumbu X =  38.65811
# Waktu =  1.33  s
#
# Posisi di sumbu Y =  18.31943
# Posisi di sumbu X =  38.82985
# Waktu =  1.34  s
#
# Posisi di sumbu Y =  18.30607
# Posisi di sumbu X =  38.99983
# Waktu =  1.35  s
#
# Posisi di sumbu Y =  18.29048
# Posisi di sumbu X =  39.16803
# Waktu =  1.36  s
#
# Posisi di sumbu Y =  18.27267
# Posisi di sumbu X =  39.33445
# Waktu =  1.37  s
#
# Posisi di sumbu Y =  18.25263
# Posisi di sumbu X =  39.4991
# Waktu =  1.38  s
#
# Posisi di sumbu Y =  18.23038
# Posisi di sumbu X =  39.66198
# Waktu =  1.39  s
#
# Posisi di sumbu Y =  18.2059
# Posisi di sumbu X =  39.82308
# Waktu =  1.4  s
#
# Posisi di sumbu Y =  18.17919
# Posisi di sumbu X =  39.9824
# Waktu =  1.41  s
#
# Posisi di sumbu Y =  18.15027
# Posisi di sumbu X =  40.13995
# Waktu =  1.42  s
#
# Posisi di sumbu Y =  18.11911
# Posisi di sumbu X =  40.29573
# Waktu =  1.43  s
#
# Posisi di sumbu Y =  18.08574
# Posisi di sumbu X =  40.44973
# Waktu =  1.44  s
#
# Posisi di sumbu Y =  18.05014
# Posisi di sumbu X =  40.60195
# Waktu =  1.45  s
#
# Posisi di sumbu Y =  18.01232
# Posisi di sumbu X =  40.7524
# Waktu =  1.46  s
#
# Posisi di sumbu Y =  17.97228
# Posisi di sumbu X =  40.90108
# Waktu =  1.47  s
#
# Posisi di sumbu Y =  17.93001
# Posisi di sumbu X =  41.04798
# Waktu =  1.48  s
#
# Posisi di sumbu Y =  17.88552
# Posisi di sumbu X =  41.19311
# Waktu =  1.49  s
#
# Posisi di sumbu Y =  17.83881
# Posisi di sumbu X =  41.33646
# Waktu =  1.5  s
#
# Posisi di sumbu Y =  17.78987
# Posisi di sumbu X =  41.47804
# Waktu =  1.51  s
#
# Posisi di sumbu Y =  17.73871
# Posisi di sumbu X =  41.61784
# Waktu =  1.52  s
#
# Posisi di sumbu Y =  17.68532
# Posisi di sumbu X =  41.75587
# Waktu =  1.53  s
#
# Posisi di sumbu Y =  17.62972
# Posisi di sumbu X =  41.89212
# Waktu =  1.54  s
#
# Posisi di sumbu Y =  17.57189
# Posisi di sumbu X =  42.0266
# Waktu =  1.55  s
#
# Posisi di sumbu Y =  17.51183
# Posisi di sumbu X =  42.1593
# Waktu =  1.56  s
#
# Posisi di sumbu Y =  17.44955
# Posisi di sumbu X =  42.29023
# Waktu =  1.57  s
#
# Posisi di sumbu Y =  17.38505
# Posisi di sumbu X =  42.41938
# Waktu =  1.58  s
#
# Posisi di sumbu Y =  17.31833
# Posisi di sumbu X =  42.54676
# Waktu =  1.59  s
#
# Posisi di sumbu Y =  17.24938
# Posisi di sumbu X =  42.67236
# Waktu =  1.6  s
#
# Posisi di sumbu Y =  17.17821
# Posisi di sumbu X =  42.79619
# Waktu =  1.61  s
#
# Posisi di sumbu Y =  17.10482
# Posisi di sumbu X =  42.91824
# Waktu =  1.62  s
#
# Posisi di sumbu Y =  17.0292
# Posisi di sumbu X =  43.03852
# Waktu =  1.63  s
#
# Posisi di sumbu Y =  16.95136
# Posisi di sumbu X =  43.15703
# Waktu =  1.64  s
#
# Posisi di sumbu Y =  16.87129
# Posisi di sumbu X =  43.27375
# Waktu =  1.65  s
#
# Posisi di sumbu Y =  16.789
# Posisi di sumbu X =  43.38871
# Waktu =  1.66  s
#
# Posisi di sumbu Y =  16.70449
# Posisi di sumbu X =  43.50189
# Waktu =  1.67  s
#
# Posisi di sumbu Y =  16.61776
# Posisi di sumbu X =  43.61329
# Waktu =  1.68  s
#
# Posisi di sumbu Y =  16.5288
# Posisi di sumbu X =  43.72292
# Waktu =  1.69  s
#
# Posisi di sumbu Y =  16.43762
# Posisi di sumbu X =  43.83078
# Waktu =  1.7  s
#
# Posisi di sumbu Y =  16.34422
# Posisi di sumbu X =  43.93686
# Waktu =  1.71  s
#
# Posisi di sumbu Y =  16.24859
# Posisi di sumbu X =  44.04116
# Waktu =  1.72  s
#
# Posisi di sumbu Y =  16.15074
# Posisi di sumbu X =  44.14369
# Waktu =  1.73  s
#
# Posisi di sumbu Y =  16.05066
# Posisi di sumbu X =  44.24445
# Waktu =  1.74  s
#
# Posisi di sumbu Y =  15.94836
# Posisi di sumbu X =  44.34343
# Waktu =  1.75  s
#
# Posisi di sumbu Y =  15.84384
# Posisi di sumbu X =  44.44064
# Waktu =  1.76  s
#
# Posisi di sumbu Y =  15.7371
# Posisi di sumbu X =  44.53607
# Waktu =  1.77  s
#
# Posisi di sumbu Y =  15.62813
# Posisi di sumbu X =  44.62972
# Waktu =  1.78  s
#
# Posisi di sumbu Y =  15.51694
# Posisi di sumbu X =  44.72161
# Waktu =  1.79  s
#
# Posisi di sumbu Y =  15.40352
# Posisi di sumbu X =  44.81171
# Waktu =  1.8  s
#
# Posisi di sumbu Y =  15.28789
# Posisi di sumbu X =  44.90004
# Waktu =  1.81  s
#
# Posisi di sumbu Y =  15.17003
# Posisi di sumbu X =  44.9866
# Waktu =  1.82  s
#
# Posisi di sumbu Y =  15.04994
# Posisi di sumbu X =  45.07138
# Waktu =  1.83  s
#
# Posisi di sumbu Y =  14.92763
# Posisi di sumbu X =  45.15439
# Waktu =  1.84  s
#
# Posisi di sumbu Y =  14.8031
# Posisi di sumbu X =  45.23562
# Waktu =  1.85  s
#
# Posisi di sumbu Y =  14.67635
# Posisi di sumbu X =  45.31508
# Waktu =  1.86  s
#
# Posisi di sumbu Y =  14.54737
# Posisi di sumbu X =  45.39276
# Waktu =  1.87  s
#
# Posisi di sumbu Y =  14.41617
# Posisi di sumbu X =  45.46867
# Waktu =  1.88  s
#
# Posisi di sumbu Y =  14.28274
# Posisi di sumbu X =  45.54281
# Waktu =  1.89  s
#
# Posisi di sumbu Y =  14.14709
# Posisi di sumbu X =  45.61516
# Waktu =  1.9  s
#
# Posisi di sumbu Y =  14.00922
# Posisi di sumbu X =  45.68575
# Waktu =  1.91  s
#
# Posisi di sumbu Y =  13.86913
# Posisi di sumbu X =  45.75456
# Waktu =  1.92  s
#
# Posisi di sumbu Y =  13.72681
# Posisi di sumbu X =  45.82159
# Waktu =  1.93  s
#
# Posisi di sumbu Y =  13.58227
# Posisi di sumbu X =  45.88685
# Waktu =  1.94  s
#
# Posisi di sumbu Y =  13.4355
# Posisi di sumbu X =  45.95033
# Waktu =  1.95  s
#
# Posisi di sumbu Y =  13.28652
# Posisi di sumbu X =  46.01204
# Waktu =  1.96  s
#
# Posisi di sumbu Y =  13.1353
# Posisi di sumbu X =  46.07198
# Waktu =  1.97  s
#
# Posisi di sumbu Y =  12.98187
# Posisi di sumbu X =  46.13014
# Waktu =  1.98  s
#
# Posisi di sumbu Y =  12.82621
# Posisi di sumbu X =  46.18652
# Waktu =  1.99  s
#
# Posisi di sumbu Y =  12.66833
# Posisi di sumbu X =  46.24113
# Waktu =  2.0  s
#
# Posisi di sumbu Y =  12.50822
# Posisi di sumbu X =  46.29397
# Waktu =  2.01  s
#
# Posisi di sumbu Y =  12.3459
# Posisi di sumbu X =  46.34503
# Waktu =  2.02  s
#
# Posisi di sumbu Y =  12.18135
# Posisi di sumbu X =  46.39431
# Waktu =  2.03  s
#
# Posisi di sumbu Y =  12.01457
# Posisi di sumbu X =  46.44183
# Waktu =  2.04  s
#
# Posisi di sumbu Y =  11.84557
# Posisi di sumbu X =  46.48756
# Waktu =  2.05  s
#
# Posisi di sumbu Y =  11.67435
# Posisi di sumbu X =  46.53152
# Waktu =  2.06  s
#
# Posisi di sumbu Y =  11.50091
# Posisi di sumbu X =  46.57371
# Waktu =  2.07  s
#
# Posisi di sumbu Y =  11.32524
# Posisi di sumbu X =  46.61412
# Waktu =  2.08  s
#
# Posisi di sumbu Y =  11.14734
# Posisi di sumbu X =  46.65276
# Waktu =  2.09  s
#
# Posisi di sumbu Y =  10.96723
# Posisi di sumbu X =  46.68962
# Waktu =  2.1  s
#
# Posisi di sumbu Y =  10.78489
# Posisi di sumbu X =  46.72471
# Waktu =  2.11  s
#
# Posisi di sumbu Y =  10.60033
# Posisi di sumbu X =  46.75802
# Waktu =  2.12  s
#
# Posisi di sumbu Y =  10.41354
# Posisi di sumbu X =  46.78956
# Waktu =  2.13  s
#
# Posisi di sumbu Y =  10.22454
# Posisi di sumbu X =  46.81932
# Waktu =  2.14  s
#
# Posisi di sumbu Y =  10.0333
# Posisi di sumbu X =  46.84731
# Waktu =  2.15  s
#
# Posisi di sumbu Y =  9.83985
# Posisi di sumbu X =  46.87352
# Waktu =  2.16  s
#
# Posisi di sumbu Y =  9.64417
# Posisi di sumbu X =  46.89796
# Waktu =  2.17  s
#
# Posisi di sumbu Y =  9.44627
# Posisi di sumbu X =  46.92062
# Waktu =  2.18  s
#
# Posisi di sumbu Y =  9.24614
# Posisi di sumbu X =  46.94151
# Waktu =  2.19  s
#
# Posisi di sumbu Y =  9.0438
# Posisi di sumbu X =  46.96062
# Waktu =  2.2  s
#
# Posisi di sumbu Y =  8.83922
# Posisi di sumbu X =  46.97796
# Waktu =  2.21  s
#
# Posisi di sumbu Y =  8.63243
# Posisi di sumbu X =  46.99352
# Waktu =  2.22  s
#
# Posisi di sumbu Y =  8.42341
# Posisi di sumbu X =  47.00731
# Waktu =  2.23  s
#
# Posisi di sumbu Y =  8.21217
# Posisi di sumbu X =  47.01933
# Waktu =  2.24  s
#
# Posisi di sumbu Y =  7.9987
# Posisi di sumbu X =  47.02957
# Waktu =  2.25  s
#
# Posisi di sumbu Y =  7.78301
# Posisi di sumbu X =  47.03803
# Waktu =  2.26  s
#
# Posisi di sumbu Y =  7.5651
# Posisi di sumbu X =  47.04472
# Waktu =  2.27  s
#
# Posisi di sumbu Y =  7.34497
# Posisi di sumbu X =  47.04964
# Waktu =  2.28  s
#
# Posisi di sumbu Y =  7.12261
# Posisi di sumbu X =  47.05278
# Waktu =  2.29  s
#
# Posisi di sumbu Y =  6.89803
# Posisi di sumbu X =  47.05414
# Waktu =  2.3  s
#
# Posisi di sumbu Y =  6.67122
# Posisi di sumbu X =  47.05373
# Waktu =  2.31  s
#
# Posisi di sumbu Y =  6.44219
# Posisi di sumbu X =  47.05155
# Waktu =  2.32  s
#
# Posisi di sumbu Y =  6.21094
# Posisi di sumbu X =  47.04759
# Waktu =  2.33  s
#
# Posisi di sumbu Y =  5.97746
# Posisi di sumbu X =  47.04185
# Waktu =  2.34  s
#
# Posisi di sumbu Y =  5.74177
# Posisi di sumbu X =  47.03435
# Waktu =  2.35  s
#
# Posisi di sumbu Y =  5.50384
# Posisi di sumbu X =  47.02506
# Waktu =  2.36  s
#
# Posisi di sumbu Y =  5.2637
# Posisi di sumbu X =  47.014
# Waktu =  2.37  s
#
# Posisi di sumbu Y =  5.02133
# Posisi di sumbu X =  47.00117
# Waktu =  2.38  s
#
# Posisi di sumbu Y =  4.77674
# Posisi di sumbu X =  46.98656
# Waktu =  2.39  s
#
# Posisi di sumbu Y =  4.52992
# Posisi di sumbu X =  46.97018
# Waktu =  2.4  s
#
# Posisi di sumbu Y =  4.28088
# Posisi di sumbu X =  46.95202
# Waktu =  2.41  s
#
# Posisi di sumbu Y =  4.02962
# Posisi di sumbu X =  46.93209
# Waktu =  2.42  s
#
# Posisi di sumbu Y =  3.77613
# Posisi di sumbu X =  46.91038
# Waktu =  2.43  s
#
# Posisi di sumbu Y =  3.52043
# Posisi di sumbu X =  46.8869
# Waktu =  2.44  s
#
# Posisi di sumbu Y =  3.26249
# Posisi di sumbu X =  46.86164
# Waktu =  2.45  s
#
# Posisi di sumbu Y =  3.00234
# Posisi di sumbu X =  46.83461
# Waktu =  2.46  s
#
# Posisi di sumbu Y =  2.73996
# Posisi di sumbu X =  46.8058
# Waktu =  2.47  s
#
# Posisi di sumbu Y =  2.47536
# Posisi di sumbu X =  46.77522
# Waktu =  2.48  s
#
# Posisi di sumbu Y =  2.20853
# Posisi di sumbu X =  46.74286
# Waktu =  2.49  s
#
# Posisi di sumbu Y =  1.93948
# Posisi di sumbu X =  46.70873
# Waktu =  2.5  s
#
# Posisi di sumbu Y =  1.66821
# Posisi di sumbu X =  46.67283
# Waktu =  2.51  s
#
# Posisi di sumbu Y =  1.39471
# Posisi di sumbu X =  46.63515
# Waktu =  2.52  s
#
# Posisi di sumbu Y =  1.11899
# Posisi di sumbu X =  46.59569
# Waktu =  2.53  s
#
# Posisi di sumbu Y =  0.84105
# Posisi di sumbu X =  46.55446
# Waktu =  2.54  s
#
# Posisi di sumbu Y =  0.56089
# Posisi di sumbu X =  46.51145
# Waktu =  2.55  s
#
# Posisi di sumbu Y =  0.2785
# Posisi di sumbu X =  46.46667
# Waktu =  2.56  s
#
# Posisi di sumbu Y =  -0.00612
# Posisi di sumbu X =  46.42012
# Waktu =  2.57  s
#
# ============ ANALITIK ============
# Posisi di sumbu Y =  0.27958
# Posisi di sumbu X =  46.64818
# Waktu =  2.57  s
